# %% [markdown]
# ## **Predictive Maintenance Project**
# **MLOps Project**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install dvc
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/117.0 kB ? eta -:--:--
#      ---------- ----------------------------- 30.7/117.0 kB ? eta -:--:--
#      ---------- ----------------------------- 30.7/117.0 kB ? eta -:--:--
#      ---------- ----------------------------- 30.7/117.0 kB ? eta -:--:--
#      ---------- ----------------------------- 30.7/117.0 kB ? eta -:--:--
#      ---------- ----------------------------- 30.7/117.0 kB ? eta -:--:--
#      ---------- ----------------------------- 30.7/117.0 kB ? eta -:--:--
#      ---------- ----------------------------- 30.7/117.0 kB ? eta -:--:--
#      ---------------------------------- - 112.6/117.0 kB 261.9 kB/s eta 0:00:01
#      ------------------------------------ 117.0/117.0 kB 253.1 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
